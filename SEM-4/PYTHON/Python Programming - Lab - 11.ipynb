# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Python Programming - 2301CS404</b></center>
# <center><b><h1>Lab - 11</b></center>
# <center><b><h1>RUDRA CHAVDA</b></center>
# <center><b><h1>23010101048</b></center>
# <pre>

# %% [markdown]
# # Modules

# %% [markdown]
# ### 01) WAP to create Calculator module which defines functions like add, sub,mul and div.
# ### Create another .py file that uses the functions available in Calculator module.

# %% [markdown]
# ### 02) WAP to pick a random character from a given String.

# %%
import random as r
string = "Rudra Chavda"

print(r.choice(string))
# Out:
# u

# %% [markdown]
# ### 03) WAP to pick a random element from a given list.

# %%
import random as r
list = [1,2,3,4,5,6]

print(r.choice(list))
# Out:
# 6

# %% [markdown]
# ### 04) WAP to roll a dice in such a way that every time you get the same number.

# %%
import random as r
dice = [1,2,3,4,5,6]

r.seed(6)
print(r.choice(dice))
# Out:
# 5

# %% [markdown]
# ### 05) WAP to generate 3 random integers between 100 and 999 which is divisible by 5.

# %%
import random

count = 1
while count<=3:
    n = random.randint(100,999)
    if n%5==0:
        print(n)
        count+=1
# Out:
# 130
# 835
# 470

# %% [markdown]
# ### 06) WAP to generate 100 random lottery tickets and pick two lucky tickets from it and announce them as Winner and Runner up respectively.

# %%
ts = r.sample(range(100,999),100)

t1 = r.choice(ts)
ts.remove(t1)

t2 = r.choice(ts)
print("Winner : ",t1)
print("Runner up : ",t2)
# Out:
# Winner :  440
# Runner up :  993

# %% [markdown]
# ### 07) WAP to print current date and time in Python.

# %%
import datetime as dt
print(dt.datetime.now())
# Out:
# 2025-02-19 10:25:30.743616

# %% [markdown]
# ### 08) Subtract a week (7 days) from a given date in Python.

# %%
from datetime import timedelta

datet = dt.datetime.now() - timedelta(days=7)
print(datet)
# Out:
# 2025-02-12 10:38:42.870871

# %% [markdown]
# ### 09) WAP to Calculate number of days between two given dates.

# %%
datet = dt.datetime.now() - dt.datetime(2025,1,20)
print(datet.days)
# Out:
# 30

# %% [markdown]
# ### 10) WAP to Find the day of the week of a given date.(i.e. wether it is sunday/monday/tuesday/etc.)

# %%
days_of_week = ["Mon","Tue","Wed","Thurs","Fri","Sat","Sun"]
datet = dt.datetime(2025,2,23)
print(days_of_week[datet.weekday()])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 date1 = datetime.now()
#       2 days_of_week = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
#       4 dayOfWeek = days_of_week[date1.weekday()]
#
# NameError: name 'datetime' is not defined

# %% [markdown]
# ### 11) WAP to demonstrate the use of date time module.

# %% [markdown]
# ### 12) WAP to demonstrate the use of the math module.
