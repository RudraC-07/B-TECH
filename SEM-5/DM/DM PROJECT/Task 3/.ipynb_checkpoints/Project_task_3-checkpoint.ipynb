# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('heart.csv')
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
df.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.tail(5)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
df['age']
# Out:
# 0       52
# 1       53
# 2       70
# 3       61
# 4       62
#         ..
# 1020    59
# 1021    60
# 1022    47
# 1023    50
# 1024    54
# Name: age, Length: 1025, dtype: int64

# %%
df[df['age']>18]
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df['age'].min()
# Out:
# 29

# %%
df['age'].max()
# Out:
# 77

# %%
df['age'].mean()
# Out:
# 54.43414634146342

# %%
df['age'].std()
# Out:
# 9.072290233244281

# %%
df['chol'].sum()
# Out:
# 252150

# %%
df['trestbps'].median()
# Out:
# 130.0

# %%
df['sex'].value_counts()
# Out:
# sex
# 1    713
# 0    312
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (1025, 14)

# %%
df.groupby('sex')['age'].sum()
# Out:
# sex
# 0    17425
# 1    38370
# Name: age, dtype: int64

# %%
df['Have_fbs'] = df['fbs'].apply(lambda x : x == 1)
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target  Have_fbs
# ...

# %%
df.rename(columns={'fbs':'Fasting_Blood_Sugar'},inplace = True)
df
# Out:
#       age  sex  cp  trestbps  chol  Fasting_Blood_Sugar  restecg  thalach  \
# 0      52    1   0       125   212                    0        1      168
# 1      53    1   0       140   203                    1        0      155
# 2      70    1   0       145   174                    0        1      125
# 3      61    1   0       148   203                    0        1      161
# 4      62    0   0       138   294                    1        1      106
# ...   ...  ...  ..       ...   ...                  ...      ...      ...
# 1020   59    1   1       140   221                    0        1      164
# 1021   60    1   0       125   258                    0        0      141
# 1022   47    1   0       110   275                    0        0      118
# 1023   50    0   0       110   254                    0        0      159
# 1024   54    1   0       120   188                    0        1      113
#
#       exang  oldpeak  slope  ca  thal  target  Have_fbs
# ...

# %%
df.sort_values(by = 'age',ascending=False)
# Out:
#      age  sex  cp  trestbps  chol  Fasting_Blood_Sugar  restecg  thalach  \
# 387   77    1   0       125   304                    0        0      162
# 162   77    1   0       125   304                    0        0      162
# 160   77    1   0       125   304                    0        0      162
# 965   76    0   2       140   197                    0        2      116
# 99    76    0   2       140   197                    0        2      116
# ..   ...  ...  ..       ...   ...                  ...      ...      ...
# 779   34    0   1       118   210                    0        1      192
# 668   29    1   1       130   204                    0        0      202
# 118   29    1   1       130   204                    0        0      202
# 60    29    1   1       130   204                    0        0      202
# 64    29    1   1       130   204                    0        0      202
#
#      exang  oldpeak  slope  ca  thal  target  Have_fbs
# ...

# %%
df.drop_duplicates()
# Out:
#      age  sex  cp  trestbps  chol  Fasting_Blood_Sugar  restecg  thalach  \
# 0     52    1   0       125   212                    0        1      168
# 1     53    1   0       140   203                    1        0      155
# 2     70    1   0       145   174                    0        1      125
# 3     61    1   0       148   203                    0        1      161
# 4     62    0   0       138   294                    1        1      106
# ..   ...  ...  ..       ...   ...                  ...      ...      ...
# 723   68    0   2       120   211                    0        0      115
# 733   44    0   2       108   141                    0        1      175
# 739   52    1   0       128   255                    0        1      161
# 843   59    1   3       160   273                    0        0      125
# 878   54    1   0       120   188                    0        1      113
#
#      exang  oldpeak  slope  ca  thal  target  Have_fbs
# ...

# %%
df.isnull().sum()
# Out:
# age                    0
# sex                    0
# cp                     0
# trestbps               0
# chol                   0
# Fasting_Blood_Sugar    0
# restecg                0
# thalach                0
# exang                  0
# oldpeak                0
# slope                  0
# ca                     0
# thal                   0
# target                 0
# Have_fbs               0
# dtype: int64

# %%
df['slope'].nunique()
# Out:
# 3

# %%
df['age'] = df['age'].astype('string')
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     52    1   0       125   212    0        1      168      0      1.0
# 1     53    1   0       140   203    1        0      155      1      3.1
# 2     70    1   0       145   174    0        1      125      1      2.6
# 3     61    1   0       148   203    0        1      161      0      0.0
# 4     62    0   0       138   294    1        1      106      0      1.9
# ...   ..  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020  59    1   1       140   221    0        1      164      1      0.0
# 1021  60    1   0       125   258    0        0      141      1      2.8
# 1022  47    1   0       110   275    0        0      118      1      1.0
# 1023  50    0   0       110   254    0        0      159      0      0.0
# 1024  54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df.sample()
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 330  37    0   2       120   215    0        1      170      0      0.0
#
#      slope  ca  thal  target
# 330      2   0     2       1

# %%
df.describe()
# Out:
#                sex           cp     trestbps        chol          fbs  \
# count  1025.000000  1025.000000  1025.000000  1025.00000  1025.000000
# mean      0.695610     0.942439   131.611707   246.00000     0.149268
# std       0.460373     1.029641    17.516718    51.59251     0.356527
# min       0.000000     0.000000    94.000000   126.00000     0.000000
# 25%       0.000000     0.000000   120.000000   211.00000     0.000000
# 50%       1.000000     1.000000   130.000000   240.00000     0.000000
# 75%       1.000000     2.000000   140.000000   275.00000     0.000000
# max       1.000000     3.000000   200.000000   564.00000     1.000000
#
#            restecg      thalach        exang      oldpeak        slope  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.529756   149.114146     0.336585     1.071512     1.385366
# std       0.527878    23.005724     0.472772     1.175053     0.617755
# ...

# %%
df['chol'].plot.box()
# Out:
# <Axes: >
